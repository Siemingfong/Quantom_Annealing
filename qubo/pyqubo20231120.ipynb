# %% [markdown]
# Copyright (C) 2023 Sean Ming-Fong Sie <seansie07@gmail.com>
#
# This work is licensed under the Creative Commons Attribution-NonCommercial
# 4.0 International License. To view a copy of this license, visit
# http://creativecommons.org/licenses/by-nc/4.0/ or send a letter to
# Creative Commons, PO Box 1866, Mountain View, CA 94042, USA.

# %%
from pyqubo import Spin
# set S = {4, 2, 7, 1}
s1, s2, s3, s4 = Spin("s1"), Spin("s2"), Spin("s3"), Spin("s4")
# Quadratic Unconstrained Binary Optimization（QUBO）for **2 as Hamiltonian 
H = (4*s1 + 2*s2 + 7*s3 + s4)**2
print("QUBO Hamiltonian:",H)
# Compile Quantum Computer or Classical Binary Optimization Solver as Hamiltonian to a model
model = H.compile()
print("Model:", model)
# Convert QUBO to Ising Hamiltonian, and get the offset as constant
qubo, offset = model.to_qubo()
print("QUBO Result:",qubo)
print("Offset:", offset)
# Out:
# QUBO Hamiltonian: ((Spin('s4') + (7.000000 * Spin('s3')) + (4.000000 * Spin('s1')) + (2.000000 * Spin('s2'))) * (Spin('s4') + (7.000000 * Spin('s3')) + (4.000000 * Spin('s1')) + (2.000000 * Spin('s2'))))
# Model: <cpp_pyqubo.Model object at 0x7fd6b0807370>
# QUBO Result: {('s1', 's1'): -160.0, ('s4', 's2'): 16.0, ('s3', 's1'): 224.0, ('s2', 's2'): -96.0, ('s4', 's1'): 32.0, ('s1', 's2'): 64.0, ('s3', 's2'): 112.0, ('s3', 's3'): -196.0, ('s4', 's4'): -52.0, ('s4', 's3'): 56.0}
# Offset: 196.0

# %%
import neal
sampler = neal.SimulatedAnnealingSampler() # Simulated Annealing Sampler using D-Wave
print("Sampler:", sampler)
bqm = model.to_bqm() # Convert QUBO to Binary Quadratic Model
print("Binary Quadratic Model:", bqm)
sampleset = sampler.sample(bqm, num_reads=10) # Retrieve 10 samples
print("Sample Set:", sampleset)
decoded_samples = model.decode_sampleset(sampleset) # Decode the sampleset
print("Decoded Sample:", decoded_samples)
best_sample = min(decoded_samples, key=lambda x: x.energy) # Retrieve the best sample
print("Best Sample:", best_sample)
best_sample.sample # doctest: +SKIP, Retrieve the best sample's value
print("Best Sample:", best_sample.sample)
# Out:
# Sampler: <dwave.samplers.sa.sampler.SimulatedAnnealingSampler object at 0x7fd690ebdbb0>
# Binary Quadratic Model: BinaryQuadraticModel({'s4': -52.0, 's2': -96.0, 's3': -196.0, 's1': -160.0}, {('s2', 's4'): 16.0, ('s3', 's4'): 56.0, ('s3', 's2'): 112.0, ('s1', 's4'): 32.0, ('s1', 's2'): 64.0, ('s1', 's3'): 224.0}, 196.0, 'BINARY')
# Sample Set:   s1 s2 s3 s4 energy num_oc.
# 0  1  1  0  1    0.0       1
# 1  1  1  0  1    0.0       1
# 3  1  1  0  1    0.0       1
# 4  1  1  0  1    0.0       1
# 5  1  1  0  1    0.0       1
# 6  0  0  1  0    0.0       1
# 7  0  0  1  0    0.0       1
# 8  0  0  1  0    0.0       1
# 9  1  1  0  1    0.0       1
# 2  1  1  0  0    4.0       1
# ['BINARY', 10 rows, 10 samples, 4 variables]
# Decoded Sample: [DecodedSolution({s3:1, s4:0, s2:0, s1:0}, energy=0.000000), DecodedSolution({s1:0, s2:0, s4:0, s3:1}, energy=0.000000), DecodedSolution({s3:1, s4:0, s2:0, s1:0}, energy=0.000000), DecodedSolution({s3:0, s4:1, s2:1, s1:1}, energy=0.000000), DecodedSolution({s1:1, s2:1, s4:1, s3:0}, energy=0.000000), DecodedSolution({s1:1, s2:1, s4:1, s3:0}, energy=0.000000), DecodedSolution({s1:1, s2:1, s4:1, s3:0}, energy=0.000000), DecodedSolution({s1:1, s2:1, s4:1, s3:0}, energy=0.000000), DecodedSolution({s3:0, s4:1, s2:1, s1:1}, energy=0.000000), DecodedSolution({s3:0, s4:0, s2:1, s1:1}, energy=4.000000)]
# Best Sample: DecodedSolution({s3:1, s4:0, s2:0, s1:0}, energy=0.000000)
# Best Sample: {'s3': 1, 's4': 0, 's2': 0, 's1': 0}

# %%
import pandas as pd
from pyqubo import Binary

# 指定CSV檔案的路徑
file_path = "../data_p/data.address.csv"

# 使用pandas的read_csv函數讀取CSV檔案
df = pd.read_csv(file_path)
print(df)

# 選擇要用於構建QUBO的列名，並且加上 class
selected_columns = df.columns[1:10].tolist() + ["class"]

# 從DataFrame中選擇所需的列
selected_data = df[selected_columns].copy()

# 預處理步驟
# 例如，使用中位數進行二元化
for col in selected_columns:
    if selected_data[col].dtype != 'object':
        median_val = selected_data[col].median()
        selected_data[col] = selected_data[col].apply(lambda x: 1 if x > median_val else 0)

# 創建QUBO模型
qubo_model = 0
for col in selected_columns:
    qubo_model += sum(selected_data[col]) * Binary(col)

# 添加特徵間的交互項（可選）
for i in range(len(selected_columns)):
    for j in range(i+1, len(selected_columns)):
        col_i = selected_columns[i]
        col_j = selected_columns[j]
        qubo_model += Binary(col_i) * Binary(col_j) * sum(selected_data[col_i] * selected_data[col_j])

# 添加偏移量以使所有特徵都為0時，Hamiltonian的值為100
desired_offset = 100
qubo_model += desired_offset

# 編譯模型
compiled_model = qubo_model.compile()

# 轉換為QUBO並獲取偏移量
qubo, offset = compiled_model.to_qubo()

# 顯示結果
print("QUBO Hamiltonian:", qubo_model)
print("Model:", compiled_model)
print("QUBO Result:", qubo)
print("Offset:", offset)
# Out:
#     n_tx  total_days  total_spent_btc  total_received_btc  total_spent_usd  \
# 0    1.0         1.0         0.012863            0.012863         9.529224
# 1    1.0         1.0         0.000275            0.000275         0.203728
# 2    1.0         1.0         0.163000            0.163000       112.258102
# 3    3.0         1.0         0.093739            0.093739        64.558030
# 4    3.0         1.0         0.000300            0.000300         0.206610
# ..   ...         ...              ...                 ...              ...
# 87   1.0         1.0         1.130100            1.130100       778.299884
# 88   1.0         1.0         0.084900            0.084900        62.896380
# 89   3.0         2.0         0.004823            0.004823         3.428225
# 90   1.0         1.0         0.114600            0.114600        84.899001
# 91   1.0         1.0         1.937600            1.937600      1362.588108
#
#     total_received_usd  mean_balance_btc  std_balance_btc  mean_balance_usd  \
# 0             9.529224          0.012863     0.000000e+00          9.529224
# 1             0.203728          0.000275     0.000000e+00          0.203728
# 2           112.258102          0.163000     0.000000e+00        112.258102
# 3            64.558030          0.031246     3.552683e-05         21.519343
# 4             0.206610          0.000100     0.000000e+00          0.068870
# ..                 ...               ...              ...               ...
# 87          778.299884          1.130100     0.000000e+00        778.299884
# 88           62.896380          0.084900     0.000000e+00         62.896380
# 89            3.428225          0.001608     1.610536e-08          1.142742
# 90           84.899001          0.114600     0.000000e+00         84.899001
# 91         1362.588108          1.937600     0.000000e+00       1362.588108
#
#     std_balance_usd  ...  dist_spend_4th_moment  dist_receive_1st_moment  \
# 0          0.000000  ...                    NaN                 0.000000
# 1          0.000000  ...                    NaN                 0.000000
# 2          0.000000  ...                    NaN                 0.000000
# 3         16.850649  ...                    1.5                 9.333333
# 4          0.000000  ...                    1.5                 2.666667
# ..              ...  ...                    ...                      ...
# 87         0.000000  ...                    NaN                 0.000000
# 88         0.000000  ...                    NaN                 0.000000
# 89         0.008553  ...                    1.5               133.333333
# 90         0.000000  ...                    NaN                 0.000000
# 91         0.000000  ...                    NaN                 0.000000
#
#     dist_receive_2nd_moment  dist_receive_3rd_moment  dist_receive_4th_moment  \
# 0                  0.000000                      NaN                      NaN
# 1                  0.000000                      NaN                      NaN
# 2                  0.000000                      NaN                      NaN
# 3                 54.222222                -0.135062                      1.5
# 4                  6.222222                 0.381802                      1.5
# ..                      ...                      ...                      ...
# 87                 0.000000                      NaN                      NaN
# 88                 0.000000                      NaN                      NaN
# 89             10238.888889                -0.311369                      1.5
# 90                 0.000000                      NaN                      NaN
# 91                 0.000000                      NaN                      NaN
#
#     dist_payback_1st_moment  dist_payback_2nd_moment  dist_payback_3rd_moment  \
# 0                  0.000000                 0.000000                      NaN
# 1                  0.000000                 0.000000                      NaN
# 2                  0.000000                 0.000000                      NaN
# 3                  9.333333                54.222222                -0.135062
# 4                  2.666667                 6.222222                 0.381802
# ..                      ...                      ...                      ...
# 87                 0.000000                 0.000000                      NaN
# 88                 0.000000                 0.000000                      NaN
# 89               133.333333             10238.888889                -0.311369
# 90                 0.000000                 0.000000                      NaN
# 91                 0.000000                 0.000000                      NaN
#
#     dist_payback_4th_moment  class
# 0                       NaN      0
# 1                       NaN      0
# 2                       NaN      0
# 3                       1.5      2
# 4                       1.5      2
# ..                      ...    ...
# 87                      NaN      5
# 88                      NaN      5
# 89                      1.5      1
# 90                      NaN      5
# 91                      NaN      5
#
# [92 rows x 69 columns]
# QUBO Hamiltonian: (100.000000 + ((Binary('std_balance_usd') * Binary('class')) * 6.000000) + ((Binary('mean_balance_usd') * Binary('class')) * 12.000000) + ((Binary('mean_balance_usd') * Binary('std_balance_usd')) * 5.000000) + ((Binary('std_balance_btc') * Binary('class')) * 6.000000) + ((Binary('std_balance_btc') * Binary('std_balance_usd')) * 13.000000) + ((Binary('std_balance_btc') * Binary('mean_balance_usd')) * 5.000000) + ((Binary('mean_balance_btc') * Binary('class')) * 12.000000) + ((Binary('mean_balance_btc') * Binary('std_balance_usd')) * 5.000000) + ((Binary('mean_balance_btc') * Binary('mean_balance_usd')) * 45.000000) + ((Binary('mean_balance_btc') * Binary('std_balance_btc')) * 5.000000) + ((Binary('total_received_usd') * Binary('class')) * 13.000000) + ((Binary('total_received_usd') * Binary('std_balance_usd')) * 8.000000) + ((Binary('total_received_usd') * Binary('mean_balance_usd')) * 43.000000) + ((Binary('total_received_usd') * Binary('std_balance_btc')) * 8.000000) + ((Binary('total_received_usd') * Binary('mean_balance_btc')) * 43.000000) + ((Binary('total_spent_usd') * Binary('class')) * 13.000000) + ((Binary('total_spent_usd') * Binary('std_balance_usd')) * 8.000000) + ((Binary('total_spent_usd') * Binary('mean_balance_usd')) * 43.000000) + ((Binary('total_spent_usd') * Binary('std_balance_btc')) * 8.000000) + ((Binary('total_spent_usd') * Binary('mean_balance_btc')) * 43.000000) + ((Binary('total_spent_usd') * Binary('total_received_usd')) * 46.000000) + ((Binary('total_received_btc') * Binary('class')) * 13.000000) + ((Binary('total_received_btc') * Binary('std_balance_usd')) * 8.000000) + ((Binary('total_received_btc') * Binary('mean_balance_usd')) * 43.000000) + ((Binary('total_received_btc') * Binary('std_balance_btc')) * 8.000000) + ((Binary('total_received_btc') * Binary('mean_balance_btc')) * 43.000000) + ((Binary('total_received_btc') * Binary('total_received_usd')) * 46.000000) + ((Binary('total_received_btc') * Binary('total_spent_usd')) * 46.000000) + ((Binary('total_spent_btc') * Binary('class')) * 13.000000) + ((Binary('total_spent_btc') * Binary('std_balance_usd')) * 8.000000) + ((Binary('total_spent_btc') * Binary('mean_balance_usd')) * 43.000000) + ((Binary('total_spent_btc') * Binary('std_balance_btc')) * 8.000000) + ((Binary('total_spent_btc') * Binary('mean_balance_btc')) * 43.000000) + ((Binary('total_spent_btc') * Binary('total_received_usd')) * 46.000000) + ((Binary('total_spent_btc') * Binary('total_spent_usd')) * 46.000000) + ((Binary('total_spent_btc') * Binary('total_received_btc')) * 46.000000) + ((Binary('total_days') * Binary('class')) * 1.000000) + ((Binary('total_days') * Binary('std_balance_usd')) * 4.000000) + ((Binary('total_days') * Binary('mean_balance_usd')) * 1.000000) + ((Binary('total_days') * Binary('std_balance_btc')) * 4.000000) + ((Binary('total_days') * Binary('mean_balance_btc')) * 1.000000) + ((Binary('total_days') * Binary('total_received_usd')) * 2.000000) + ((Binary('total_days') * Binary('total_spent_usd')) * 2.000000) + ((Binary('total_days') * Binary('total_received_btc')) * 2.000000) + ((Binary('total_days') * Binary('total_spent_btc')) * 2.000000) + (16.000000 * Binary('class')) + (13.000000 * Binary('std_balance_usd')) + (46.000000 * Binary('mean_balance_usd')) + (14.000000 * Binary('std_balance_btc')) + (46.000000 * Binary('mean_balance_btc')) + (46.000000 * Binary('total_received_usd')) + (46.000000 * Binary('total_spent_usd')) + (46.000000 * Binary('total_received_btc')) + (46.000000 * Binary('total_spent_btc')) + 0.000000 + (4.000000 * Binary('total_days')))
# Model: <cpp_pyqubo.Model object at 0x7fd6b10265b0>
# QUBO Result: {('class', 'class'): 16.0, ('total_received_btc', 'total_spent_btc'): 46.0, ('std_balance_btc', 'total_received_btc'): 8.0, ('total_spent_usd', 'total_spent_btc'): 46.0, ('total_days', 'total_days'): 4.0, ('mean_balance_usd', 'total_days'): 1.0, ('total_spent_btc', 'total_spent_btc'): 46.0, ('std_balance_usd', 'total_received_usd'): 8.0, ('class', 'mean_balance_btc'): 12.0, ('mean_balance_btc', 'total_spent_btc'): 43.0, ('mean_balance_usd', 'mean_balance_btc'): 45.0, ('total_spent_usd', 'total_received_btc'): 46.0, ('class', 'std_balance_btc'): 6.0, ('mean_balance_usd', 'total_received_usd'): 43.0, ('std_balance_usd', 'total_days'): 4.0, ('class', 'mean_balance_usd'): 12.0, ('class', 'total_spent_btc'): 13.0, ('std_balance_btc', 'total_spent_usd'): 8.0, ('total_received_usd', 'total_spent_btc'): 46.0, ('mean_balance_btc', 'total_received_btc'): 43.0, ('std_balance_usd', 'std_balance_usd'): 13.0, ('mean_balance_usd', 'total_spent_btc'): 43.0, ('total_spent_usd', 'total_days'): 2.0, ('std_balance_usd', 'class'): 6.0, ('mean_balance_usd', 'mean_balance_usd'): 46.0, ('total_received_btc', 'total_days'): 2.0, ('std_balance_usd', 'mean_balance_usd'): 5.0, ('class', 'total_days'): 1.0, ('mean_balance_btc', 'mean_balance_btc'): 46.0, ('mean_balance_usd', 'total_spent_usd'): 43.0, ('class', 'total_spent_usd'): 13.0, ('std_balance_btc', 'total_spent_btc'): 8.0, ('std_balance_usd', 'total_spent_btc'): 8.0, ('std_balance_usd', 'std_balance_btc'): 13.0, ('total_spent_btc', 'total_days'): 2.0, ('class', 'total_received_btc'): 13.0, ('class', 'total_received_usd'): 13.0, ('mean_balance_btc', 'total_received_usd'): 43.0, ('mean_balance_usd', 'total_received_btc'): 43.0, ('total_received_btc', 'total_received_btc'): 46.0, ('std_balance_btc', 'mean_balance_btc'): 5.0, ('std_balance_usd', 'total_received_btc'): 8.0, ('std_balance_usd', 'total_spent_usd'): 8.0, ('mean_balance_btc', 'total_spent_usd'): 43.0, ('total_spent_usd', 'total_spent_usd'): 46.0, ('total_received_usd', 'total_received_usd'): 46.0, ('total_received_usd', 'total_days'): 2.0, ('std_balance_usd', 'mean_balance_btc'): 5.0, ('std_balance_btc', 'total_received_usd'): 8.0, ('mean_balance_btc', 'total_days'): 1.0, ('total_received_usd', 'total_spent_usd'): 46.0, ('total_received_usd', 'total_received_btc'): 46.0, ('mean_balance_usd', 'std_balance_btc'): 5.0, ('std_balance_btc', 'total_days'): 4.0, ('std_balance_btc', 'std_balance_btc'): 14.0}
# Offset: 100.0

# %%
import neal
from pyqubo import Binary

# 編譯為模型
compiled_model = qubo_model.compile()
print("Model:", compiled_model)

# 將 QUBO 轉換為二元二次模型
bqm = compiled_model.to_bqm()
print("Binary Quadratic Model:", bqm)

# 使用模擬退火算法
sampler = neal.SimulatedAnnealingSampler()
print("Sampler:", sampler)

# 採樣10次
num_reads = 10
sampleset = sampler.sample(bqm, num_reads=num_reads)
print("Sample Set:", sampleset)

# 解碼採樣結果
decoded_samples = compiled_model.decode_sampleset(sampleset)
print("Decoded Sample:", decoded_samples)

# 尋找能量最低的樣本
best_sample = min(decoded_samples, key=lambda x: x.energy)
print("Best Sample:", best_sample)

# 獲取最佳樣本的值
best_sample_value = best_sample.sample
print("Best Sample:", best_sample_value)
# Out:
# Model: <cpp_pyqubo.Model object at 0x7fd6b1031230>
# Binary Quadratic Model: BinaryQuadraticModel({'std_balance_usd': 13.0, 'total_received_usd': 46.0, 'std_balance_btc': 14.0, 'total_received_btc': 46.0, 'total_spent_usd': 46.0, 'total_spent_btc': 46.0, 'mean_balance_usd': 46.0, 'total_days': 4.0, 'class': 16.0, 'mean_balance_btc': 46.0}, {('total_received_usd', 'std_balance_usd'): 8.0, ('std_balance_btc', 'std_balance_usd'): 13.0, ('std_balance_btc', 'total_received_usd'): 8.0, ('total_received_btc', 'std_balance_usd'): 8.0, ('total_received_btc', 'total_received_usd'): 46.0, ('total_received_btc', 'std_balance_btc'): 8.0, ('total_spent_usd', 'std_balance_usd'): 8.0, ('total_spent_usd', 'total_received_usd'): 46.0, ('total_spent_usd', 'std_balance_btc'): 8.0, ('total_spent_usd', 'total_received_btc'): 46.0, ('total_spent_btc', 'std_balance_usd'): 8.0, ('total_spent_btc', 'total_received_usd'): 46.0, ('total_spent_btc', 'std_balance_btc'): 8.0, ('total_spent_btc', 'total_received_btc'): 46.0, ('total_spent_btc', 'total_spent_usd'): 46.0, ('mean_balance_usd', 'std_balance_usd'): 5.0, ('mean_balance_usd', 'total_received_usd'): 43.0, ('mean_balance_usd', 'std_balance_btc'): 5.0, ('mean_balance_usd', 'total_received_btc'): 43.0, ('mean_balance_usd', 'total_spent_usd'): 43.0, ('mean_balance_usd', 'total_spent_btc'): 43.0, ('total_days', 'std_balance_usd'): 4.0, ('total_days', 'total_received_usd'): 2.0, ('total_days', 'std_balance_btc'): 4.0, ('total_days', 'total_received_btc'): 2.0, ('total_days', 'total_spent_usd'): 2.0, ('total_days', 'total_spent_btc'): 2.0, ('total_days', 'mean_balance_usd'): 1.0, ('class', 'std_balance_usd'): 6.0, ('class', 'total_received_usd'): 13.0, ('class', 'std_balance_btc'): 6.0, ('class', 'total_received_btc'): 13.0, ('class', 'total_spent_usd'): 13.0, ('class', 'total_spent_btc'): 13.0, ('class', 'mean_balance_usd'): 12.0, ('class', 'total_days'): 1.0, ('mean_balance_btc', 'std_balance_usd'): 5.0, ('mean_balance_btc', 'total_received_usd'): 43.0, ('mean_balance_btc', 'std_balance_btc'): 5.0, ('mean_balance_btc', 'total_received_btc'): 43.0, ('mean_balance_btc', 'total_spent_usd'): 43.0, ('mean_balance_btc', 'total_spent_btc'): 43.0, ('mean_balance_btc', 'mean_balance_usd'): 45.0, ('mean_balance_btc', 'total_days'): 1.0, ('mean_balance_btc', 'class'): 12.0}, 100.0, 'BINARY')
# Sampler: <dwave.samplers.sa.sampler.SimulatedAnnealingSampler object at 0x7fd6a03ca220>
# Sample Set:   class mean_balance_btc mean_balance_usd ... total_spent_usd energy num_oc.
# 0     0                0                0 ...               0  100.0       1
# 1     0                0                0 ...               0  100.0       1
# 2     0                0                0 ...               0  100.0       1
# 3     0                0                0 ...               0  100.0       1
# 4     0                0                0 ...               0  100.0       1
# 5     0                0                0 ...               0  100.0       1
# 6     0                0                0 ...               0  100.0       1
# 7     0                0                0 ...               0  100.0       1
# 8     0                0                0 ...               0  100.0       1
# 9     0                0                0 ...               0  100.0       1
# ['BINARY', 10 rows, 10 samples, 10 variables]
# Decoded Sample: [DecodedSolution({total_spent_usd:0, total_received_usd:0, total_received_btc:0, total_days:0, total_spent_btc:0, class:0, std_balance_btc:0, mean_balance_btc:0, std_balance_usd:0, mean_balance_usd:0}, energy=100.000000), DecodedSolution({mean_balance_usd:0, std_balance_usd:0, mean_balance_btc:0, std_balance_btc:0, class:0, total_spent_btc:0, total_days:0, total_received_btc:0, total_received_usd:0, total_spent_usd:0}, energy=100.000000), DecodedSolution({total_spent_usd:0, total_received_usd:0, total_received_btc:0, total_days:0, total_spent_btc:0, class:0, std_balance_btc:0, mean_balance_btc:0, std_balance_usd:0, mean_balance_usd:0}, energy=100.000000), DecodedSolution({total_spent_usd:0, total_received_usd:0, total_received_btc:0, total_days:0, total_spent_btc:0, class:0, std_balance_btc:0, mean_balance_btc:0, std_balance_usd:0, mean_balance_usd:0}, energy=100.000000), DecodedSolution({mean_balance_usd:0, std_balance_usd:0, mean_balance_btc:0, std_balance_btc:0, class:0, total_spent_btc:0, total_days:0, total_received_btc:0, total_received_usd:0, total_spent_usd:0}, energy=100.000000), DecodedSolution({mean_balance_usd:0, std_balance_usd:0, mean_balance_btc:0, std_balance_btc:0, class:0, total_spent_btc:0, total_days:0, total_received_btc:0, total_received_usd:0, total_spent_usd:0}, energy=100.000000), DecodedSolution({mean_balance_usd:0, std_balance_usd:0, mean_balance_btc:0, std_balance_btc:0, class:0, total_spent_btc:0, total_days:0, total_received_btc:0, total_received_usd:0, total_spent_usd:0}, energy=100.000000), DecodedSolution({mean_balance_usd:0, std_balance_usd:0, mean_balance_btc:0, std_balance_btc:0, class:0, total_spent_btc:0, total_days:0, total_received_btc:0, total_received_usd:0, total_spent_usd:0}, energy=100.000000), DecodedSolution({total_spent_usd:0, total_received_usd:0, total_received_btc:0, total_days:0, total_spent_btc:0, class:0, std_balance_btc:0, mean_balance_btc:0, std_balance_usd:0, mean_balance_usd:0}, energy=100.000000), DecodedSolution({total_spent_usd:0, total_received_usd:0, total_received_btc:0, total_days:0, total_spent_btc:0, class:0, std_balance_btc:0, mean_balance_btc:0, std_balance_usd:0, mean_balance_usd:0}, energy=100.000000)]
# Best Sample: DecodedSolution({total_spent_usd:0, total_received_usd:0, total_received_btc:0, total_days:0, total_spent_btc:0, class:0, std_balance_btc:0, mean_balance_btc:0, std_balance_usd:0, mean_balance_usd:0}, energy=100.000000)
# Best Sample: {'total_spent_usd': 0, 'total_received_usd': 0, 'total_received_btc': 0, 'total_days': 0, 'total_spent_btc': 0, 'class': 0, 'std_balance_btc': 0, 'mean_balance_btc': 0, 'std_balance_usd': 0, 'mean_balance_usd': 0}
